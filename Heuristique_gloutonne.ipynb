# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# %%
def format_file(file_name, path="."): #path="drive/My Drive/JSPLIB/"
    jobs = []
    with open(path+"/instances/"+file_name,"r") as file:    
        f = file.readlines()
        for i in range(5, len(f)):
            jobs.append(f[i].split())
            
        return np.array(jobs), f[4]

# %%
class Task:
    def __init__(self, resource, duration, job, number):
        self.number = number
        self.resource = resource
        self.duration = duration
        self.job = job

# %%
class Job:
    def __init__(self, number):
        self.tasks = []
        self.number = number
        self.next_availability = 0
        self.current_task_idx = -1
        self.is_done = False
        
    def add_task(self, task):
        self.tasks.append(task)
        
    def set_next_availability(self, new_duration):
        self.next_availability = new_duration
        if (self.current_task_idx == len(self.tasks) - 1): # if we've already reached the last task
            self.is_done = True
            
    def get_next_task(self, cycle):
        if ((self.next_availability <= cycle) & (not self.is_done)):          
            self.current_task_idx += 1
            return self.tasks[self.current_task_idx]
        return None

# %%
class Resource:
    def __init__(self, number):
        self.number = number
        self.next_availability = 0
        self.current_task = None
        self.tmp_tasks = []
        self.all_tasks = []
        
    def set_next_availability(self, new_duration):
        self.next_availability = new_duration

# %%
def insert_task(task, priority): 
    '''Insert task in its corresponding ressource waiting list with respect to %s priority'''%(priority)
    sorted_list = task.resource.tmp_tasks
    index=len(sorted_list) # Insert in last position if no condition is satisfied
    # Searching for the position 
    for i in range(len(sorted_list)): 
        if (((sorted_list[i].duration < task.duration) & (priority == 'LPT')) | ((sorted_list[i].duration > task.duration) & (priority == 'SPT'))):             
            index = i 
            break
      
    # Inserting in the list
    sorted_list.insert(index, task)

# %%
def insert_task_randomly(task):
    '''Insert task in its corresponding ressource waiting list randomly'''
    random_index = round(np.random.random_sample() * len(task.resource.tmp_tasks))

    # Inserting in the list
    task.resource.tmp_tasks.insert(random_index, task)

# %%
def reorder_tasks(resources, waiting_tasks, priority):
    for task in waiting_tasks:
        if priority:
          insert_task(task, priority)
        else:
          insert_task_randomly(task)

    print("Resources")    
    for resource in resources:
        for tmp_task in resource.tmp_tasks: 
            old_av = max(resource.next_availability, tmp_task.job.next_availability)
            resource.set_next_availability(old_av + tmp_task.duration) # Update availability on resource
            tmp_task.job.set_next_availability(old_av + tmp_task.duration) # Update availability on job
            resource.all_tasks.append(("J{} - T{}".format(int(tmp_task.job.number), int(tmp_task.number)), old_av ,resource.next_availability))

        print("R%i"%(resource.number))        
        print(resource.all_tasks)
        # Flash resources waiting tasks
        resource.tmp_tasks = []
    
    print("-"*100) # Display separator

# %%
def get_available_tasks(jobs, cycle):
    tasks = []
    for job in jobs:
        task = job.get_next_task(cycle)
        if (task):
            tasks.append(task)
        else:
            if(job.is_done):
                jobs.remove(job)
    print("Available Tasks (Not assigned to a resource)")
    print([(task.job.number, task.resource.number) for task in tasks])
    return tasks, jobs

# %%
# Main Program
jobs = []
resources = []
cycle = 0
priority = None # "LPT", "SPT", None(Random)
job_list, shape = format_file("ft06")
number_of_ressources = int(shape.split()[1])

# Initialization
## Create Ressource instances
for i in range(number_of_ressources):
    resources.append(Resource(number=i))
    
## Create Job then Task instances    
job_index = 1
for line in job_list:
    job = Job(job_index)
    for k in range(0,len(line),2):
        resource_nbr = int(line[k])
        duration = int(line[k+1])
        task = Task(resources[resource_nbr], duration, job, k/2)
        job.add_task(task)
    
    jobs.append(job)
    job_index+=1

# %%
# Launching the program
print("Jobshop 6x6 with an %s priority"%(priority))
print("-"*100)
while(jobs != []):
    print("Cycle: {}".format(cycle))    
    waiting_tasks, new_jobs = get_available_tasks(jobs, cycle) # Tasks that needs to be assigned to one ressource
    reorder_tasks(resources, waiting_tasks, priority)
    jobs = new_jobs # Update job list: if a job is done, it will be removed from the list
    cycle += 1
# Out:
# Jobshop 6x6 with an None priority
# ----------------------------------------------------------------------------------------------------
# Cycle: 0
# Available Tasks (Not assigned to a resource)
# [(1, 2), (2, 1), (3, 2), (4, 1), (5, 2), (6, 1)]
# Resources
# R0
# []
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# []
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 1
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# []
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# []
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 2
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# []
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# []
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 3
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# []
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# []
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 4
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# []
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# []
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 5
# Available Tasks (Not assigned to a resource)
# [(3, 3), (4, 0)]
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 6
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 7
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 8
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# []
# ----------------------------------------------------------------------------------------------------
# Cycle: 9
# Available Tasks (Not assigned to a resource)
# [(3, 5)]
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 10
# Available Tasks (Not assigned to a resource)
# [(4, 2)]
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 11
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 12
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 13
# Available Tasks (Not assigned to a resource)
# [(2, 2)]
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 14
# Available Tasks (Not assigned to a resource)
# [(5, 1)]
# Resources
# R0
# [('J4 - T1', 5, 10)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 15
# Available Tasks (Not assigned to a resource)
# [(1, 0)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 16
# Available Tasks (Not assigned to a resource)
# [(6, 3)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 17
# Available Tasks (Not assigned to a resource)
# [(3, 0)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 18
# Available Tasks (Not assigned to a resource)
# [(1, 1)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19)]
# R4
# []
# R5
# [('J3 - T2', 9, 17)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 19
# Available Tasks (Not assigned to a resource)
# [(5, 4), (6, 5)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19)]
# R4
# [('J5 - T2', 19, 24)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 20
# Available Tasks (Not assigned to a resource)
# [(4, 3)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23)]
# R4
# [('J5 - T2', 19, 24)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 21
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23)]
# R4
# [('J5 - T2', 19, 24)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 22
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23)]
# R4
# [('J5 - T2', 19, 24)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 23
# Available Tasks (Not assigned to a resource)
# [(4, 4)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 24
# Available Tasks (Not assigned to a resource)
# [(5, 5)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 25
# Available Tasks (Not assigned to a resource)
# [(1, 3), (2, 4)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 26
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 27
# Available Tasks (Not assigned to a resource)
# [(3, 1)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 28
# Available Tasks (Not assigned to a resource)
# [(3, 4), (6, 0)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 29
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 30
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 31
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 32
# Available Tasks (Not assigned to a resource)
# [(1, 5), (4, 5), (5, 0)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 33
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 34
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 35
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 36
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 37
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 38
# Available Tasks (Not assigned to a resource)
# [(6, 4)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 39
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 40
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 41
# Available Tasks (Not assigned to a resource)
# [(5, 3)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 42
# Available Tasks (Not assigned to a resource)
# [(2, 5)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 43
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 44
# Available Tasks (Not assigned to a resource)
# [(1, 4)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 45
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 46
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 47
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 48
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 49
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 50
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 51
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 52
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 53
# Available Tasks (Not assigned to a resource)
# [(6, 2)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 54
# Available Tasks (Not assigned to a resource)
# [(2, 0)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 55
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 56
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 57
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 58
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 59
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 60
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 61
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 62
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 63
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 64
# Available Tasks (Not assigned to a resource)
# [(2, 3)]
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42), ('J2 - T5', 64, 68)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
# Cycle: 65
# Available Tasks (Not assigned to a resource)
# []
# Resources
# R0
# [('J4 - T1', 5, 10), ('J1 - T1', 15, 18), ('J3 - T3', 18, 27), ('J6 - T3', 28, 38), ('J5 - T4', 38, 41), ('J2 - T4', 54, 64)]
# R1
# [('J4 - T0', 0, 5), ('J2 - T0', 5, 13), ('J6 - T0', 13, 16), ('J5 - T1', 16, 19), ('J1 - T2', 19, 25), ('J3 - T4', 27, 28)]
# R2
# [('J3 - T0', 0, 5), ('J5 - T0', 5, 14), ('J1 - T0', 14, 15), ('J4 - T2', 15, 20), ('J2 - T1', 20, 25), ('J6 - T5', 53, 54)]
# R3
# [('J3 - T1', 5, 9), ('J6 - T1', 16, 19), ('J4 - T3', 20, 23), ('J1 - T3', 25, 32), ('J5 - T5', 41, 42), ('J2 - T5', 64, 68)]
# R4
# [('J5 - T2', 19, 24), ('J4 - T4', 24, 32), ('J2 - T2', 32, 42), ('J3 - T5', 42, 49), ('J6 - T4', 49, 53), ('J1 - T5', 53, 59)]
# R5
# [('J3 - T2', 9, 17), ('J6 - T2', 19, 28), ('J5 - T3', 28, 32), ('J4 - T5', 32, 41), ('J1 - T4', 41, 44), ('J2 - T3', 44, 54)]
# ----------------------------------------------------------------------------------------------------
